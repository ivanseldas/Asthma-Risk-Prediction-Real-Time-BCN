# %%
import pandas as pd 

df_inhaler = pd.read_parquet("../data/raw/iot_inhaler/inhaler_events.parquet", engine='pyarrow')
df_air_quality = pd.read_parquet("../data/processed/air_quality/air_quality.parquet", engine='pyarrow')

# %%
import pandas as pd 
df = pd.read_parquet("../data/processed/inhaler_air_merged/", engine='pyarrow')

# %%
len(df), len(df_air_quality), len(df_inhaler)
# Out:
# (8760000, 339839, 8760000)

# %%
df_inhaler.head()
# Out:
#   patient_id           timestamp  puffs   latitude  longitude  \
# 0   PAT-0000 2024-01-01 00:00:00      0  41.362295   2.136105
# 1   PAT-0000 2024-01-01 01:00:00      1  41.352363   2.135321
# 2   PAT-0000 2024-01-01 02:00:00      0  41.358916   2.136313
# 3   PAT-0000 2024-01-01 03:00:00      0  41.361088   2.130443
# 4   PAT-0000 2024-01-01 04:00:00      0  41.357983   2.122362
#
#             device_type        date
# 0  Symbicort Turbuhaler  2024-01-01
# 1  Symbicort Turbuhaler  2024-01-01
# 2  Symbicort Turbuhaler  2024-01-01
# 3  Symbicort Turbuhaler  2024-01-01
# 4  Symbicort Turbuhaler  2024-01-01

# %%
df_air_quality.head()
# Out:
#             timestamp  Estacio   Nom_districte  Longitud  Latitud  \
# 0 2019-04-02 01:00:00      4.0      Sant Marti    2.2045  41.4039
# 1 2019-04-02 01:00:00     42.0  Sants-Montjuic    2.1331  41.3788
# 2 2019-04-02 01:00:00     43.0        Eixample    2.1538  41.3853
# 3 2019-04-02 01:00:00     44.0          Gracia    2.1534  41.3987
# 4 2019-04-02 01:00:00     50.0    Ciutat Vella    2.1874  41.3864
#
#    NO2 (µg/m³)  O3 (µg/m³)  PM2.5 (µg/m³)
# 0         22.0        47.0            8.0
# 1         29.0        47.0            8.0
# 2         27.0        75.0           10.0
# 3         56.0        44.0            8.0
# 4         32.0        64.0            8.0

# %%
# First install required packages: 
# pip install geopandas shapely

import geopandas as gpd
from shapely.geometry import Point

# Download official boundaries (2023):
path = '../data/raw/geodata_barcelona_districts/BarcelonaCiutat_Districtes.json'

# Load shapefile
districts = gpd.read_file(path) 

def get_district(lat, lon):
    point = Point(lon, lat)
    for idx, row in districts.iterrows():
        if row['geometry'].contains(point):
            return row['NOM']
    return None

# Add district column
df_inhaler['district'] = df_inhaler.apply(
    lambda row: get_district(row['latitude'], row['longitude']), 
    axis=1
)
# Out:
# /home/ivanseldasp/anaconda3/envs/asthma-realtime-py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 10000/10000 [00:28<00:00, 345.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
