# %%
import pandas as pd

# %%
df_inhaler = pd.read_parquet("../data/raw/iot_inhaler/inhaler_events.parquet", engine='pyarrow')
df_patients = pd.read_parquet("../data/raw/iot_inhaler/patients.parquet", engine='pyarrow')
df_air_quality = pd.read_parquet("../data/processed/air_quality/air_quality.parquet", engine='pyarrow')

# %%
df_inhaler.head()
# Out:
#   patient_id           timestamp  puffs   latitude  longitude  \
# 0   PAT-0000 2024-01-01 00:00:00      0  41.360109   2.133112
# 1   PAT-0000 2024-01-01 01:00:00      1  41.360069   2.133109
# 2   PAT-0000 2024-01-01 02:00:00      0  41.360095   2.133113
# 3   PAT-0000 2024-01-01 03:00:00      0  41.360104   2.133089
# 4   PAT-0000 2024-01-01 04:00:00      0  41.360092   2.133057
#
#             device_type        district        date
# 0  Symbicort Turbuhaler  Sants-Montjuic  2024-01-01
# 1  Symbicort Turbuhaler  Sants-Montjuic  2024-01-01
# 2  Symbicort Turbuhaler  Sants-Montjuic  2024-01-01
# 3  Symbicort Turbuhaler  Sants-Montjuic  2024-01-01
# 4  Symbicort Turbuhaler  Sants-Montjuic  2024-01-01

# %%
df_patients.head()
# Out:
#   patient_id gender  age   home_district        gema_severity   work_district  \
# 0   PAT-0000      F   62  Sants-Montjuic         Intermittent  Sants-Montjuic
# 1   PAT-0001      M   45       Les Corts      Mild Persistent      Sant Marti
# 2   PAT-0002      F   39      Sant Marti  Moderate Persistent      Sant Marti
# 3   PAT-0003      M   41      Sant Marti         Intermittent      Sant Marti
# 4   PAT-0004      F   43    Ciutat Vella         Intermittent    Ciutat Vella
#
#    symbicort_adherence  base_exacerbation_risk  has_allergic_rhinitis  \
# 0             0.540804                0.073104                      0
# 1             0.721616                0.115664                      1
# 2             0.587797                0.241747                      0
# 3             0.581592                0.068209                      1
# 4             0.417218                0.087934                      1
#
#    has_COPD
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df_air_quality.head()
# Out:
#             timestamp  Estacio   Nom_districte  Longitud  Latitud  \
# 0 2019-04-02 01:00:00      4.0      Sant Marti    2.2045  41.4039
# 1 2019-04-02 01:00:00     42.0  Sants-Montjuic    2.1331  41.3788
# 2 2019-04-02 01:00:00     43.0        Eixample    2.1538  41.3853
# 3 2019-04-02 01:00:00     44.0          Gracia    2.1534  41.3987
# 4 2019-04-02 01:00:00     50.0    Ciutat Vella    2.1874  41.3864
#
#    NO2 (µg/m³)  O3 (µg/m³)  PM2.5 (µg/m³)
# 0         22.0        47.0            8.0
# 1         29.0        47.0            8.0
# 2         27.0        75.0           10.0
# 3         56.0        44.0            8.0
# 4         32.0        64.0            8.0

# %%
df_air_quality['Nom_districte'].unique()
# Out:
# array(['Sant Marti', 'Sants-Montjuic', 'Eixample', 'Gracia',
#        'Ciutat Vella', 'Horta-Guinardo', 'Les Corts'], dtype=object)

# %%
df_air_quality.rename(columns={'Nom_districte':'district',
                               'Estacio': 'station',
                               'Longitud': 'longitude',
                               'Latitud': 'latitude'},
                      inplace=True)

# %%
df_inhaler_columns = ['patient_id', 'timestamp', 'puffs','longitude', 'latitude']
df_air_quality_columns = ['timestamp', 'station', 'district', 'PM2.5 (µg/m³)','NO2 (µg/m³)', 'O3 (µg/m³)']

# %%
df_inhaler_columns = ['patient_id', 'timestamp', 'puffs', 'district','longitude', 'latitude']
df_air_quality_columns = ['timestamp', 'station', 'district', 'PM2.5 (µg/m³)','NO2 (µg/m³)', 'O3 (µg/m³)']
df_patients_columns = ['patient_id', 'gender', 'age', 'gema_severity', 'symbicort_adherence', 'base_exacerbation_risk', 'has_allergic_rhinitis', 'has_COPD']

# Convert timestamps to datetime and floor to hourly frequency
df_inhaler['timestamp'] = pd.to_datetime(df_inhaler['timestamp']).dt.floor('h')
df_air_quality['timestamp'] = pd.to_datetime(df_air_quality['timestamp']).dt.floor('h')

# Merge air quality data
merged_df = pd.merge(
    df_inhaler[df_inhaler_columns],
    df_air_quality[df_air_quality_columns],
    on=['district', 'timestamp'],
    how='left'
)

# %%
merged_df.head()
# Out:
#   patient_id           timestamp  puffs        district  longitude   latitude  \
# 0   PAT-0000 2024-01-01 00:00:00      0  Sants-Montjuic   2.133112  41.360109
# 1   PAT-0000 2024-01-01 01:00:00      1  Sants-Montjuic   2.133109  41.360069
# 2   PAT-0000 2024-01-01 02:00:00      0  Sants-Montjuic   2.133113  41.360095
# 3   PAT-0000 2024-01-01 03:00:00      0  Sants-Montjuic   2.133089  41.360104
# 4   PAT-0000 2024-01-01 04:00:00      0  Sants-Montjuic   2.133057  41.360092
#
#    station  PM2.5 (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)
# 0     42.0           8.10         42.0        49.0
# 1     42.0           8.00         42.0        47.0
# 2     42.0           8.00         53.0        46.0
# 3     42.0           7.73         47.0        46.0
# 4     42.0           7.45         26.0        45.0

# %%
# Select and order final columns
merged_df.to_parquet("../data/processed/inhaler_air_merged/", engine='pyarrow', partition_cols=['patient_id'])
