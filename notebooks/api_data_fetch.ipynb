# %%
import requests
import pandas as pd
import json

# %%
# 1. Get dataset metadata
def get_dataset_resources(dataset_name, api_url):
    response = requests.get(api_url, params={"id": dataset_name})
    dataset_info = response.json()

    # List available resources from dataset
    resources = dataset_info['result']['resources']
    return resources

# 2. Download all dataset resources
def download_resource(resource_id, resources, format_type):
    base_url = "https://opendata-ajuntament.barcelona.cat/data/api/action/"
    
    csv_url = next(r['url'] for r in resources if r['id'] == resource_id)
    
    return pd.read_csv(csv_url, sep=",", encoding='ISO-8859-1')

# 3. Download and save files
def export_dataset_files(dataset_name, api_url, output_folder):
    
    resources = get_dataset_resources(dataset_name, api_url)
    
    for resource in resources:
        try:
            df = download_resource(resource['id'], resources, resource['format'])
            df_name = f"{resource['name']}"
            df.to_csv(f"{output_folder}/{df_name}", index=False, encoding='ISO-8859-1')
            print(f"✅ {df_name} saved ({len(df)} registers)")
        except Exception as e:
            print(f"❌ Error in {resource['id']}: {str(e)}")
            

datasets = ["qualitat-aire-detall-bcn", "qualitat-aire-estacions-bcn"]
api_url = "https://opendata-ajuntament.barcelona.cat/data/api/action/package_show"

for dataset_name in datasets:
    output_folder = f"../data/raw/{dataset_name}/"
    export_dataset_files(dataset_name=dataset_name, api_url=api_url, output_folder=output_folder)
# Out:
# ✅ Qualitat_Aire_Detall.csv guardado (280 registros)
# ✅ 2025_01_Gener_qualitat_aire_BCN.csv guardado (2170 registros)
# ✅ 2024_01_Gener_qualitat_aire_BCN.csv guardado (1987 registros)
# ✅ 2024_02_Febrer_qualitat_aire_BCN.csv guardado (1856 registros)
# ✅ 2024_03_Marc_qualitat_aire_BCN.csv guardado (1984 registros)
# ✅ 2024_04_Abril_qualitat_aire_BCN.csv guardado (1920 registros)
# ✅ 2024_06_Juny_qualitat_aire_BCN.csv guardado (1870 registros)
# ✅ 2024_07_Juliol_qualitat_aire_BCN.csv guardado (2077 registros)
# ✅ 2024_08_Agost_qualitat_aire_BCN.csv guardado (2077 registros)
# ✅ 2024_09_Setembre_qualitat_aire_BCN.csv guardado (2010 registros)
# ✅ 2024_10_Octubre_qualitat_aire_BCN.csv guardado (2077 registros)
# ✅ 2024_11_Novembre_qualitat_aire_BCN.csv guardado (2052 registros)
# ✅ 2024_12_Desembre_qualitat_aire_BCN.csv guardado (2170 registros)
# ✅ 2023_01_Gener_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2023_02_Febrer_qualitat_aire_BCN.csv guardado (1820 registros)
# ✅ 2023_03_Marc_qualitat_aire_BCN.csv guardado (2029 registros)
# ✅ 2023_04_Abril_qualitat_aire_BCN.csv guardado (1980 registros)
# ✅ 2023_05_Maig_qualitat_aire_BCN.csv guardado (2046 registros)
# ✅ 2023_06_Juny_qualitat_aire_BCN.csv guardado (1980 registros)
# ✅ 2023_07_Juliol_qualitat_aire_BCN.csv guardado (2039 registros)
# ✅ 2023_08_Agost_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2023_09_Setembre_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2023_10_Octubre_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2023_11_Novembre_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2023_12_Desembre_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2022_01_Gener_qualitat_aire_BCN.csv guardado (1705 registros)
# ✅ 2022_02_Febrer_qualitat_aire_BCN.csv guardado (1562 registros)
# ✅ 2022_03_Marc_qualitat_aire_BCN.csv guardado (1987 registros)
# ✅ 2022_04_Abril_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2022_05_Maig_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2022_06_Juny_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2022_07_Juliol_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2022_08_Agost_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2022_09_Setembre_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2022_10_Octubre_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2022_11_Novembre_qualitat_aire_BCN.csv guardado (1950 registros)
# ✅ 2022_12_Desembre_qualitat_aire_BCN.csv guardado (2015 registros)
# ✅ 2021_01_Gener_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2021_02_Febrer_qualitat_aire_BCN.csv guardado (1372 registros)
# ✅ 2021_03_Marc_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2021_04_Abril_qualitat_aire_BCN.csv guardado (1480 registros)
# ✅ 2021_05_Maig_qualitat_aire_BCN.csv guardado (1674 registros)
# ✅ 2021_06_Juny_qualitat_aire_BCN.csv guardado (1620 registros)
# ✅ 2021_07_Juliol_qualitat_aire_BCN.csv guardado (1674 registros)
# ✅ 2021_08_Agost_qualitat_aire_BCN.csv guardado (1674 registros)
# ✅ 2021_09_Setembre_qualitat_aire_BCN.csv guardado (1620 registros)
# ✅ 2021_10_Octubre_qualitat_aire_BCN.csv guardado (1674 registros)
# ✅ 2021_11_Novembre_qualitat_aire_BCN.csv guardado (1587 registros)
# ✅ 2021_12_Desembre_qualitat_aire_BCN.csv guardado (1705 registros)
# ✅ 2020_01_Gener_qualitat_aire_BCN.csv guardado (1279 registros)
# ✅ 2020_02_Febrer_qualitat_aire_BCN.csv guardado (1305 registros)
# ✅ 2020_03_Marc_qualitat_aire_BCN.csv guardado (1395 registros)
# ✅ 2020_04_Abril_qualitat_aire_BCN.csv guardado (1378 registros)
# ✅ 2020_05_Maig_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2020_06_Juny_qualitat_aire_BCN.csv guardado (1470 registros)
# ✅ 2020_07_Juliol_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2020_08_Agost_qualitat_aire_BCN.csv guardado (1372 registros)
# ✅ 2020_09_Setembre_qualitat_aire_BCN.csv guardado (1470 registros)
# ✅ 2020_10_Octubre_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2020_11_Novembre_qualitat_aire_BCN.csv guardado (1274 registros)
# ✅ 2020_12_Desembre_qualitat_aire_BCN.csv guardado (1519 registros)
# ✅ 2019_01_Gener_qualitat_aire_BCN.csv guardado (5904 registros)
# ❌ Error en c5bfa2d3-7ca7-4be8-bffe-1141e5eb65a7: Error tokenizing data. C error: Expected 3 fields in line 8, saw 4
#
# ✅ 2019_02_Febrer_qualitat_aire_BCN.csv guardado (5376 registros)
# ❌ Error en ec75a101-e3f8-4cdb-afa6-6d637ae87c4f: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# ✅ 2019_03_Marc_qualitat_aire_BCN.csv guardado (5928 registros)
# ❌ Error en 15835309-868a-48d2-8230-84417a82fe11: Error tokenizing data. C error: Expected 1 fields in line 8, saw 2
#
# ✅ 2019_04_Abril_qualitat_aire_BCN.csv guardado (1131 registros)
# ✅ 2019_05_Maig_qualitat_aire_BCN.csv guardado (1092 registros)
# ✅ 2019_06_Juny_qualitat_aire_BCN.csv guardado (1164 registros)
# ✅ 2019_07_Juliol_qualitat_aire_BCN.csv guardado (1053 registros)
# ✅ 2019_08_Agost_qualitat_aire_BCN.csv guardado (1209 registros)
# ✅ 2019_09_Setembre_qualitat_aire_BCN.csv guardado (1131 registros)
# ✅ 2019_10_Octubre_qualitat_aire_BCN.csv guardado (1209 registros)
# ✅ 2019_11_Novembre_qualitat_aire_BCN.csv guardado (1215 registros)
# ✅ 2019_12_Desembre_qualitat_aire_BCN.csv guardado (1276 registros)
# ✅ 2018_06_Juny_qualitat_aire_BCN.csv guardado (3262 registros)
# ❌ Error en bc95939b-da5c-44d5-91b8-c992fa49be71: Error tokenizing data. C error: Expected 2 fields in line 10, saw 3
#
# ✅ 2018_07_Juliol_qualitat_aire_BCN.csv guardado (3649 registros)
# ❌ Error en 97407cfa-1e0e-4c93-9a76-feff58c6cf44: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
#
# ✅ 2018_08_Agost_qualitat_aire_BCN.csv guardado (5800 registros)
# ❌ Error en e4be7da3-cc7f-45bf-96ca-75c23c0910fb: Error tokenizing data. C error: Expected 1 fields in line 10, saw 2
#
# ✅ 2018_09_Setembre_qualitat_aire_BCN.csv guardado (5736 registros)
# ❌ Error en 1b6aa7ab-8dfc-4ba1-8274-5318866708c3: Error tokenizing data. C error: Expected 1 fields in line 6, saw 3
#
# ✅ 2018_10_Octubre_qualitat_aire_BCN.csv guardado (5944 registros)
# ❌ Error en 25a7ab1a-299d-4702-9ac3-37a22f438995: Error tokenizing data. C error: Expected 2 fields in line 3, saw 3
#
# ✅ 2018_11_Novembre_qualitat_aire_BCN.csv guardado (5744 registros)
# ❌ Error en ac83eef2-0307-4cdc-8f65-83a96a244b0b: Error tokenizing data. C error: Expected 1 fields in line 7, saw 3
#
# ✅ 2018_12_Desembre_qualitat_aire_BCN.csv guardado (5848 registros)
# ❌ Error en 44601c7a-ce04-4666-a890-4e68cfc73b37: Error tokenizing data. C error: Expected 3 fields in line 37, saw 4
#
# ✅ 2025_qualitat_aire_estacions.csv guardado (55 registros)
# ✅ 2023_qualitat_aire_estacions.csv guardado (54 registros)
# ✅ 2022_Qualitat_Aire_Estacions.csv guardado (44 registros)
# ✅ 2021_Qualitat_Aire_Estacions.csv guardado (50 registros)
# ✅ 2019_Qualitat_Aire_Estacions.csv guardado (39 registros)
# ✅ 2018_Qualitat_Aire_Estacions.csv guardado (7 registros)

# %% [markdown]
# ### IoT Data Simulator

# %%
np.random.seed(7)
n_patients = 1000  

inhaler_data = pd.DataFrame({
    "patient_id": [f"PAT_{i:04d}" for i in range(n_patients)],
    "timestamp": pd.date_range("2024-06-01", periods=n_patients, freq="h"),
    "puffs": np.random.poisson(0.3, n_patients),
    "lat": 41.3851 + np.random.normal(0, 0.01, n_patients),
    "lon": 2.1734 + np.random.normal(0, 0.01, n_patients)
})

inhaler_data.head(10)
# Out:
#   patient_id           timestamp  puffs        lat       lon
# 0   PAT_0000 2024-06-01 00:00:00      0  41.403118  2.180912
# 1   PAT_0001 2024-06-01 01:00:00      1  41.391171  2.154886
# 2   PAT_0002 2024-06-01 02:00:00      0  41.392651  2.155765
# 3   PAT_0003 2024-06-01 03:00:00      1  41.402736  2.158601
# 4   PAT_0004 2024-06-01 04:00:00      0  41.373465  2.181291
# 5   PAT_0005 2024-06-01 05:00:00      0  41.387879  2.171937
# 6   PAT_0006 2024-06-01 06:00:00      0  41.386104  2.179267
# 7   PAT_0007 2024-06-01 07:00:00      0  41.397073  2.181997
# 8   PAT_0008 2024-06-01 08:00:00      0  41.373617  2.167210
# 9   PAT_0009 2024-06-01 09:00:00      1  41.388856  2.167943
